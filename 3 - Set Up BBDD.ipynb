# %% [markdown]
# # Limpieza & Set Up de BBDD
#
# ### Realizaremos algunas customizaciones sobre la base con el fin de optimizar el trabajo de aqui en adelante:
#
#     1. Cambiar los títulos de las columnas a mayúsculas
#     2. Agregar la leyenda del índice
#     3. Limpiar los NaN por ' '
#     4. Creación de columna "DAY_OF_THE_WEEK"
#     5. Conversion de tipo de datos de las columnas Dat & AvgTalkDuration

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn

# %%
rutaexcel = r"C:\\Users\\Lucia\Desktop\\bootcamp\\Proyecto_EDA_Pablo_Mendez\\Telecom Company Call-Center-Dataset.xlsx"
bbdd = pd.read_excel(rutaexcel)
bbdd
# Out:
#      Call Id    Agent        Date      Time              Topic Answered (Y/N)  \
# 0     ID0033    Diane  2021-01-01  13:33:36  Technical Support              Y
# 1     ID0056      Dan  2021-01-01  17:44:10          Streaming              Y
# 2     ID0039  Stewart  2021-01-01  14:38:24   Contract related              Y
# 3     ID0009     Greg  2021-01-01  11:13:55      Admin Support              Y
# 4     ID0043    Diane  2021-01-01  14:47:02  Technical Support              Y
# ...      ...      ...         ...       ...                ...            ...
# 4995  ID4992      Joe  2021-03-31  14:13:55          Streaming              N
# 4996  ID4993      Joe  2021-03-31  14:18:14      Admin Support              N
# 4997  ID4994     Greg  2021-03-31  14:58:34   Contract related              N
# 4998  ID4995      Dan  2021-03-31  15:33:07    Payment related              N
# 4999  ID5000    Diane  2021-03-31  17:39:50   Contract related              N
#
#      Resolved  Speed of answer in seconds AvgTalkDuration  Satisfaction rating
# 0           Y                        57.0        00:06:49                  3.0
# 1           Y                        83.0        00:06:45                  4.0
# 2           Y                        74.0        00:06:41                  1.0
# 3           Y                        15.0        00:06:38                  4.0
# 4           Y                        45.0        00:06:21                  3.0
# ...       ...                         ...             ...                  ...
# 4995        N                         NaN             NaN                  NaN
# 4996        N                         NaN             NaN                  NaN
# 4997        N                         NaN             NaN                  NaN
# 4998        N                         NaN             NaN                  NaN
# 4999        N                         NaN             NaN                  NaN
#
# [5000 rows x 10 columns]

# %%
bbdd.columns = bbdd.columns.str.upper()
bbdd
bbdd.index.name = 'INDEX'
bbdd
# Out:
#       CALL ID    AGENT        DATE      TIME              TOPIC  \
# INDEX
# 0      ID0033    Diane  2021-01-01  13:33:36  Technical Support
# 1      ID0056      Dan  2021-01-01  17:44:10          Streaming
# 2      ID0039  Stewart  2021-01-01  14:38:24   Contract related
# 3      ID0009     Greg  2021-01-01  11:13:55      Admin Support
# 4      ID0043    Diane  2021-01-01  14:47:02  Technical Support
# ...       ...      ...         ...       ...                ...
# 4995   ID4992      Joe  2021-03-31  14:13:55          Streaming
# 4996   ID4993      Joe  2021-03-31  14:18:14      Admin Support
# 4997   ID4994     Greg  2021-03-31  14:58:34   Contract related
# 4998   ID4995      Dan  2021-03-31  15:33:07    Payment related
# 4999   ID5000    Diane  2021-03-31  17:39:50   Contract related
#
#       ANSWERED (Y/N) RESOLVED  SPEED OF ANSWER IN SECONDS AVGTALKDURATION  \
# INDEX
# 0                  Y        Y                        57.0        00:06:49
# 1                  Y        Y                        83.0        00:06:45
# 2                  Y        Y                        74.0        00:06:41
# 3                  Y        Y                        15.0        00:06:38
# 4                  Y        Y                        45.0        00:06:21
# ...              ...      ...                         ...             ...
# 4995               N        N                         NaN             NaN
# 4996               N        N                         NaN             NaN
# 4997               N        N                         NaN             NaN
# 4998               N        N                         NaN             NaN
# 4999               N        N                         NaN             NaN
#
#        SATISFACTION RATING
# INDEX
# 0                      3.0
# 1                      4.0
# 2                      1.0
# 3                      4.0
# 4                      3.0
# ...                    ...
# 4995                   NaN
# 4996                   NaN
# 4997                   NaN
# 4998                   NaN
# 4999                   NaN
#
# [5000 rows x 10 columns]

# %%
bbdd.fillna(' ')
# Out:
#       CALL ID    AGENT        DATE      TIME              TOPIC  \
# INDEX
# 0      ID0033    Diane  2021-01-01  13:33:36  Technical Support
# 1      ID0056      Dan  2021-01-01  17:44:10          Streaming
# 2      ID0039  Stewart  2021-01-01  14:38:24   Contract related
# 3      ID0009     Greg  2021-01-01  11:13:55      Admin Support
# 4      ID0043    Diane  2021-01-01  14:47:02  Technical Support
# ...       ...      ...         ...       ...                ...
# 4995   ID4992      Joe  2021-03-31  14:13:55          Streaming
# 4996   ID4993      Joe  2021-03-31  14:18:14      Admin Support
# 4997   ID4994     Greg  2021-03-31  14:58:34   Contract related
# 4998   ID4995      Dan  2021-03-31  15:33:07    Payment related
# 4999   ID5000    Diane  2021-03-31  17:39:50   Contract related
#
#       ANSWERED (Y/N) RESOLVED SPEED OF ANSWER IN SECONDS AVGTALKDURATION  \
# INDEX
# 0                  Y        Y                       57.0        00:06:49
# 1                  Y        Y                       83.0        00:06:45
# 2                  Y        Y                       74.0        00:06:41
# 3                  Y        Y                       15.0        00:06:38
# 4                  Y        Y                       45.0        00:06:21
# ...              ...      ...                        ...             ...
# 4995               N        N
# 4996               N        N
# 4997               N        N
# 4998               N        N
# 4999               N        N
#
#       SATISFACTION RATING
# INDEX
# 0                     3.0
# 1                     4.0
# 2                     1.0
# 3                     4.0
# 4                     3.0
# ...                   ...
# 4995
# 4996
# 4997
# 4998
# 4999
#
# [5000 rows x 10 columns]

# %%
bbdd['DAY_OF_THE_WEEK'] = pd.to_datetime(bbdd['DATE']).dt.day_name()
bbdd
# Out:
#       CALL ID    AGENT        DATE      TIME              TOPIC  \
# INDEX
# 0      ID0033    Diane  2021-01-01  13:33:36  Technical Support
# 1      ID0056      Dan  2021-01-01  17:44:10          Streaming
# 2      ID0039  Stewart  2021-01-01  14:38:24   Contract related
# 3      ID0009     Greg  2021-01-01  11:13:55      Admin Support
# 4      ID0043    Diane  2021-01-01  14:47:02  Technical Support
# ...       ...      ...         ...       ...                ...
# 4995   ID4992      Joe  2021-03-31  14:13:55          Streaming
# 4996   ID4993      Joe  2021-03-31  14:18:14      Admin Support
# 4997   ID4994     Greg  2021-03-31  14:58:34   Contract related
# 4998   ID4995      Dan  2021-03-31  15:33:07    Payment related
# 4999   ID5000    Diane  2021-03-31  17:39:50   Contract related
#
#       ANSWERED (Y/N) RESOLVED  SPEED OF ANSWER IN SECONDS AVGTALKDURATION  \
# INDEX
# 0                  Y        Y                        57.0        00:06:49
# 1                  Y        Y                        83.0        00:06:45
# 2                  Y        Y                        74.0        00:06:41
# 3                  Y        Y                        15.0        00:06:38
# 4                  Y        Y                        45.0        00:06:21
# ...              ...      ...                         ...             ...
# 4995               N        N                         NaN             NaN
# 4996               N        N                         NaN             NaN
# 4997               N        N                         NaN             NaN
# 4998               N        N                         NaN             NaN
# 4999               N        N                         NaN             NaN
#
#        SATISFACTION RATING DAY_OF_THE_WEEK
# INDEX
# 0                      3.0          Friday
# 1                      4.0          Friday
# 2                      1.0          Friday
# 3                      4.0          Friday
# 4                      3.0          Friday
# ...                    ...             ...
# 4995                   NaN       Wednesday
# 4996                   NaN       Wednesday
# 4997                   NaN       Wednesday
# 4998                   NaN       Wednesday
# 4999                   NaN       Wednesday
#
# [5000 rows x 11 columns]

# %%
bbdd['DAY_OF_THE_WEEK'].unique()
# Out:
# array(['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday',
#        'Thursday'], dtype=object)

# %%
#bdd['AVGTALKDURATION'] = pd.to_timedelta(bbdd['AVGTALKDURATION'])

# Convierte la duración a minutos
#bbdd['AVGTALKDURATION'] = bbdd['AVGTALKDURATION'].dt.total_seconds() / 60
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Lucia\Desktop\bootcamp\Proyecto_EDA_Pablo_Mendez\3 - Set Up BBDD.ipynb Cell 8 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lucia/Desktop/bootcamp/Proyecto_EDA_Pablo_Mendez/3%20-%20Set%20Up%20BBDD.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> bbdd.AVGTALKDURATION.sum()
#
# File c:\Users\Lucia\miniconda3\envs\.venv\Lib\site-packages\pandas\core\series.py:6200, in Series.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#    6191 @doc(make_doc("sum", ndim=1))
#    6192 def sum(
#    6193     self,
#    (...)
#    6198     **kwargs,
#    6199 ):
# -> 6200     return NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#
# File c:\Users\Lucia\miniconda3\envs\.venv\Lib\site-packages\pandas\core\generic.py:12070, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12062 def sum(
#   12063     self,
#   12064     axis: Axis | None = 0,
#    (...)
#   12068     **kwargs,
#   12069 ):
# > 12070     return self._min_count_stat_function(
#   12071         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12072     )
#
# File c:\Users\Lucia\miniconda3\envs\.venv\Lib\site-packages\pandas\core\generic.py:12053, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12050 elif axis is lib.no_default:
#   12051     axis = 0
# > 12053 return self._reduce(
#   12054     func,
#   12055     name=name,
#   12056     axis=axis,
#   12057     skipna=skipna,
#   12058     numeric_only=numeric_only,
#   12059     min_count=min_count,
#   12060 )
#
# File c:\Users\Lucia\miniconda3\envs\.venv\Lib\site-packages\pandas\core\series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6124     # GH#47500 - change to TypeError to match other methods
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\Lucia\miniconda3\envs\.venv\Lib\site-packages\pandas\core\nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      81     raise TypeError(
#      82         f"reduction operation '{f_name}' not allowed for this dtype"
#      83     )
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
#
# File c:\Users\Lucia\miniconda3\envs\.venv\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\Lucia\miniconda3\envs\.venv\Lib\site-packages\pandas\core\nanops.py:477, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     474         results = [func(x, **kwargs) for x in arrs]
#     475     return np.array(results)
# --> 477 return func(values, axis=axis, **kwargs)
#
# File c:\Users\Lucia\miniconda3\envs\.venv\Lib\site-packages\pandas\core\nanops.py:646, in nansum(values, axis, skipna, min_count, mask)
#     643 elif dtype.kind == "m":
#     644     dtype_sum = np.dtype(np.float64)
# --> 646 the_sum = values.sum(axis, dtype=dtype_sum)
#     647 the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     649 return the_sum
#
# File c:\Users\Lucia\miniconda3\envs\.venv\Lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: unsupported operand type(s) for +: 'datetime.time' and 'datetime.time'
